# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
custeda = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/Creditloan.csv")
empeda = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/Occupation.csv")
twitter_data = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/Twitter.csv")
source = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/Source.csv")
location = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/Location.csv")
language = pd.read_csv("/Users/ramvaghani/Documents/Dmdd_Assignment3/language.csv")

# %% [markdown]
# # Data completeness

# %%
custeda.isnull().sum()
# Out:
# sk_id              0
# target             0
# income             0
# education          0
# occupation_id    115
# dtype: int64

# %% [markdown]
# # The data is complete and there are no null values. occupation_id is null because of the cardinality constraint 0...1 and since occupation_id is the foreign key to the creditloan data referencing from the occupation table.

# %%
empeda.isnull().sum()
# Out:
# occupation_id    0
# role             0
# dtype: int64

# %% [markdown]
# # The data is complete

# %%
twitter_data.isnull().sum()
# Out:
# Unnamed: 0          0
# Twitter_Id          0
# Date_Published      0
# Lik210              0
# source_id           0
# Tweet               0
# Name                0
# language_id         0
#  Retweets           0
# 200titi210          0
# Lat210t24hours    170
# sk_id              59
# dtype: int64

# %% [markdown]
# # The data is complete and there are no null values. sk_id is null because of the cardinality constraint 0...1 and since sk_id is the foreign key to the twitter data referencing from the creditloan table. There can be tweet ids that did not post in the last 24 hours

# %%
source.isnull().sum()
# Out:
# source_id    0
# title        0
# dtype: int64

# %% [markdown]
# # The data is complete

# %%
location.isnull().sum()
# Out:
# location_id    0
# street name    0
# city           0
# state          0
# zipcode        0
# dtype: int64

# %% [markdown]
# # The data is complete

# %%
language.isnull().sum()
# Out:
# language_id     0
# abbreviation    0
# description     0
# dtype: int64

# %% [markdown]
# # The data is complete

# %% [markdown]
# # The graphs below validate the data accuracy

# %%
custeda.education.value_counts().plot(kind="bar")
plt.title("")
plt.xlabel("")
plt.xticks(rotation=90)
plt.ylabel("")
plt.show()

# %% [markdown]
# Maximum of our customers belong to Secondary/secondary special.

# %%
sns.catplot(x="sk_id", y="income", data=invoiceeda, kind="box", aspect=1.5)
plt.title("")
plt.show()

# %% [markdown]
# Our customer's salary mostly lie in the range of 1 lakhs to 6 lakhs annually.

# %%
custeda["occupation_id"] = custeda["occupation_id"].astype("category")

# %%
sns.catplot(x="occupation_id", y="income", data=invoiceeda, kind="box", aspect=2.0)
plt.title("")
plt.show()

# %% [markdown]
# The above graph displays the income distribution for each occupation_id.
